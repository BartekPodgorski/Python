# %%
import numpy as np
import pandas as pd
products = pd.read_csv("C:/Users/user/Desktop/Python_Main/kurs_pandas/WA_Sales_Products_2012-14.csv")
products.head()
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# 3       303      0.282938
# 4      1415      0.291450

# %%
groups = products.groupby(by = ["Retailer country","Year"])

# %%
groups.size().head(10)
# Out:
# Retailer country  Year
# Australia         2012    1402
#                   2013    1376
#                   2014     887
# Austria           2012    1436
#                   2013    1469
#                   2014     957
# Belgium           2012    1339
#                   2013    1481
#                   2014     890
# Brazil            2012    1218
# dtype: int64

# %%
groups.sum().head()
# Out:
#                            Revenue  Quantity  Gross margin
# Retailer country Year
# Australia        2012  25607043.50    522186    625.835424
#                  2013  47799737.14    839750    625.650690
#                  2014  35893188.50    638845    390.336301
# Austria          2012  34568089.63    702134    636.115492
#                  2013  44996737.04    803771    665.086198

# %%
groups.get_group(("Australia",2012)).head(10)
# Out:
#      Order method type Retailer type          Product line Product type  \
# 3735         Telephone     Golf Shop  Personal Accessories      Watches
# 3736         Telephone     Golf Shop  Personal Accessories   Binoculars
# 3737         Telephone     Golf Shop  Personal Accessories   Navigation
# 3738         Telephone     Golf Shop        Golf Equipment        Irons
# 3739         Telephone     Golf Shop        Golf Equipment        Irons
# 3740         Telephone     Golf Shop        Golf Equipment        Irons
# 3741         Telephone     Golf Shop        Golf Equipment        Irons
# 3742         Telephone     Golf Shop        Golf Equipment        Woods
# 3743         Telephone     Golf Shop        Golf Equipment        Woods
# 3744         Telephone     Golf Shop        Golf Equipment        Woods
#
#                                 Product  Quarter    Revenue  Quantity  \
# 3735               Mountain Man Digital  Q1 2012    2161.34        53
# 3736                        Seeker Mini  Q1 2012    5689.60        70
# 3737                        Glacier GPS  Q1 2012   17337.34       158
# 3738              Hailstorm Steel Irons  Q1 2012   96118.50       255
# 3739           Hailstorm Titanium Irons  Q1 2012   40149.72        46
# 3740         Lady Hailstorm Steel Irons  Q1 2012   18529.23        37
# 3741      Lady Hailstorm Titanium Irons  Q1 2012   36769.92        44
# 3742          Hailstorm Steel Woods Set  Q1 2012  140202.24       206
# 3743  Lady Hailstorm Titanium Woods Set  Q1 2012   33231.64        26
# 3744     Lady Hailstorm Steel Woods Set  Q1 2012   23116.59        27
#
#       Gross margin
# 3735      0.509564
# 3736      0.507874
# 3737      0.284152
# 3738      0.413692
# 3739      0.437513
# 3740      0.445356
# 3741      0.449550
# 3742      0.498085
# 3743      0.483116
# 3744      0.448451
