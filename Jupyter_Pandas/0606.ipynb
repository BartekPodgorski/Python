# %%
import numpy as np
import pandas as pd
products = pd.read_csv("C:/Users/user/Desktop/Python_Main/kurs_pandas/WA_Sales_Products_2012-14.csv")
products.head()
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# 3       303      0.282938
# 4      1415      0.291450

# %%
groups = products.groupby("Retailer country")
groups.head()
# Out:
#      Retailer country Order method type  Retailer type          Product line  \
# 0       United States               Fax  Outdoors Shop     Camping Equipment
# 1       United States               Fax  Outdoors Shop     Camping Equipment
# 2       United States               Fax  Outdoors Shop     Camping Equipment
# 3       United States               Fax  Outdoors Shop     Camping Equipment
# 4       United States               Fax  Outdoors Shop     Camping Equipment
# ...               ...               ...            ...                   ...
# 8310            Spain               Fax   Sports Store     Camping Equipment
# 8311            Spain               Fax   Sports Store     Camping Equipment
# 8312            Spain               Fax   Sports Store     Camping Equipment
# 8313            Spain               Fax   Sports Store  Personal Accessories
# 8314            Spain               Fax   Sports Store  Personal Accessories
#
#        Product type                    Product  Year  Quarter    Revenue  \
# 0      Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1      Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2             Tents                  Star Dome  2012  Q1 2012   89940.48
# 3             Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4     Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
# ...             ...                        ...   ...      ...        ...
# 8310   Cooking Gear        TrailChef Water Bag  2012  Q1 2012   12191.58
# 8311   Cooking Gear              TrailChef Cup  2012  Q1 2012    2994.06
# 8312  Sleeping Bags                 Hibernator  2012  Q1 2012   31882.62
# 8313        Watches        Mountain Man Analog  2012  Q1 2012    2442.90
# 8314        Eyewear                  Polar Sun  2012  Q1 2012    1360.48
#
#       Quantity  Gross margin
# 0          489      0.347548
# 1          252      0.474274
# 2          147      0.352772
# 3          303      0.282938
# 4         1415      0.291450
# ...        ...           ...
# 8310      1926      0.537125
# 8311       834      0.763231
# 8312       231      0.376902
# 8313        51      0.373695
# 8314        22      0.577135
#
# [105 rows x 11 columns]

# %%
for country in groups:
    print(country[0])
# Out:
# Australia
# Austria
# Belgium
# Brazil
# Canada
# China
# Denmark
# Finland
# France
# Germany
# Italy
# Japan
# Korea
# Mexico
# Netherlands
# Singapore
# Spain
# Sweden
# Switzerland
# United Kingdom
# United States

# %%
country_names = []
for country in groups:
    country_names.append(country[0])
print(country_names)
# Out:
# ['Australia', 'Austria', 'Belgium', 'Brazil', 'Canada', 'China', 'Denmark', 'Finland', 'France', 'Germany', 'Italy', 'Japan', 'Korea', 'Mexico', 'Netherlands', 'Singapore', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom', 'United States']
